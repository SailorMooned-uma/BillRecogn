# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
wine = pd.read_csv('wine.csv')
df = pd.DataFrame(wine)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
values = wine.describe()
values
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.countplot(df['quality'])
# Out:
# C:\Users\angel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
cov_matrix = np.cov(df, rowvar=False)
plt.figure(figsize=(12, 12))
sns.heatmap(cov_matrix, annot=True)
#Covariance matrix
# Out:
# <AxesSubplot:>

# %%
corr_matrix = np.corrcoef(df, rowvar=False)
plt.figure(figsize=(12, 12))
sns.heatmap(corr_matrix, annot=True)
#Correlation matrix
# Out:
# <AxesSubplot:>

# %%
for i in df.columns:
    sns.boxplot(x=df[i])
    plt.title(i)
    plt.show()

    sns.boxplot(x='quality', y=i, data=df)
    plt.title(i + ' vs quality')
    plt.show()

# %%
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['quality_scaled'] = scaler.fit_transform(df[['quality']])
fig = px.parallel_coordinates(df, color='quality_scaled', color_continuous_scale=px.colors.sequential.Reds)
fig.show()
# Out:
# <div>                            <div id="5bdb5f8b-92ab-4d3d-a577-654397d67405" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bdb5f8b-92ab-4d3d-a577-654397d67405")) {                    Plotly.newPlot(                        "5bdb5f8b-92ab-4d3d-a577-654397d67405",                        [{"dimensions":[{"label":"fixed acidity","values":[7.4,7.8,7.8,11.2,7.4,7.4,7.9,7.3,7.8,7.5,6.7,7.5,5.6,7.8,8.9,8.9,8.5,8.1,7.4,7.9,8.9,7.6,7.9,8.5,6.9,6.3,7.6,7.9,7.1,7.8,6.7,6.9,8.3,6.9,5.2,7.8,7.8,8.1,5.7,7.3,7.3,8.8,7.5,8.1,6.8,4.6,7.7,8.7,6.4,5.6,8.8,6.6,6.6,8.6,7.6,7.7,10.2,7.5,7.8,7.3,8.8,7.7,7.5,7.0,7.2,7.2,7.5,6.6,9.3,8.0,7.7,7.7,7.7,8.3,9.7,8.8,8.8,6.8,6.7,8.3,6.2,7.8,7.4,7.3,6.3,6.9,8.6,7.7,9.3,7.0,7.9,8.6,8.6,7.7,5.0,4.7,6.8,7.0,7.6,8.1,8.3,7.8,8.1,8.1
# ...

# %%
import pandas as pd
import plotly.express as px

dig = px.scatter(df, x="alcohol", y="pH", size="quality", color="quality", color_continuous_scale=px.colors.sequential.Blues)

dig.show()
# Out:
# <div>                            <div id="8234e48e-804f-40e8-bcef-00730b84c841" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8234e48e-804f-40e8-bcef-00730b84c841")) {                    Plotly.newPlot(                        "8234e48e-804f-40e8-bcef-00730b84c841",                        [{"hovertemplate":"alcohol=%{x}<br>pH=%{y}<br>quality=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[5,5,5,6,5,5,5,7,7,5,5,5,5,5,5,5,7,5,4,6,6,5,5,5,6,5,5,5,5,6,5,6,5,6,5,6,6,7,4,5,5,4,6,5,5,4,5,5,5,5,5,6,6,5,6,5,5,5,5,6,5,5,7,5,5,5,5,5,5,6,6,5,5,4,5,5,5,6,5,4,5,5,5,5,6,5,6,5,5,5,5,6,5,5,4,6,5,5,5,6,6,6,6,5,5,5,5,5,6,5,5,5,5,6,5,6,6,6,6,6,5,6,5,5,5,5,5,5,7,5,5,5,5,6,6,5,5,5,5,5,5,5,6,5,6,5,5,5,6,6,6,4,5,5,5,5,5,5,5,6,5,4,6,5,5,5,5,4,6,5,4,6,6,
# ...

# %%
#- ¿Qué variables tienen mayor dependencia con la calidad?
#Density, Fixed acidity y Alcohol
#- ¿Qué variables tienen datos atípicos?
#Sulphate, Sulphur Dioxide
