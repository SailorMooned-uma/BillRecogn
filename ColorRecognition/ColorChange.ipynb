# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('playera.JPG')

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#image not showing correctly by using the darcula theme
img.shape
plt.imshow(img)
plt.show()
